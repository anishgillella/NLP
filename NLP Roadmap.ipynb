# %% [markdown]
# NLP libraries:
# - NLTK
# - Spacy
#
# Deep learning libraries:
# - Pytorch
# - Keras
# - Tensorflow
# - Transformers

# %% [markdown]
# Step 1: Text processing Level 1
# - Tokenization
# - Lemmatization
# - StopWord

# %% [markdown]
# Step 2:Converting words to vectors;
# Text processing Level 2
# - Bag of Words
# - TFIDF
# - Unigram
# - Bigram
# - n-gram

# %% [markdown]
# Step 3: Text Preprocessing
# - Genism
# - Word2vec
# - AvgWord2Vec
#
# The accuracy of the tokens/chunks increase as we go through the preprocessing steps

# %% [markdown]
# Step 4: Get an understanding of Deep Learning
# - Gradient Descent
# - Stochastic gradient descent

# %% [markdown]
# Step 5: Understanding Recurrent Neural Networks, LSTM, GRU
#
# - RNNs works best with sequence data

# %% [markdown]
# Step 6: Word Embeddings, Word2vec

# %% [markdown]
# Step 7: Bidirectional LSTM RNN, Encoders, Decoders, Attention Models

# %% [markdown]
# Step 8: Transformers

# %% [markdown]
# Step 9: BERT

# %% [markdown]
# ![image.png](attachment:image.png)
